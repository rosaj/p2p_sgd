# %%
cd ..
# Out:
# /home/fipulab/notebooks/robert/p2p_sgd

# %% [markdown]
# # Sparse -> Few-NERD

# %%
from environ import set_visible_devices
set_visible_devices('GPU:1')

from p2p.train import do_train
from p2p.agents import BertAgent
from data.ner import clients_data as ner_clients_data
from models.ner import model as ner_model

do_train(agent_pars={"agent_class": BertAgent, "multi_task_optimization": False, "multi_task_differentiation": 'model'},
         agent_data_pars={"agents_data": ner_clients_data, "num_clients": 20, "batch_size": 50, 'dataset': 'few_nerd', 'dataset_fraction': 0.2},
         model_pars={"model_mod": ner_model, "bert_config": 'uncased_L-2_H-128_A-2', 'processor_name': 'few', "lr": 5e-4, "default_weights": True},
         graph_pars={'graph_type': 'sparse', 'num_neighbors': 3, 'directed': True, 'time_varying': -1},
         sim_pars={'epochs': 300, 'seed': 123, 'print_args': {'print_metrics': ['test_model-macro_avg_f1_score'], 'group_by_dataset': False}})
# Out:
# agent_pars: [{'agent_class': <class 'p2p.agents.bert_agent.BertAgent'>, 'multi_task_optimization': False, 'multi_task_differentiation': 'model'}]
# agent_data_pars: [{'agents_data': <module 'data.ner.clients_data' from '/home/fipulab/notebooks/robert/p2p_sgd/data/ner/clients_data.py'>, 'num_clients': 20, 'batch_size': 50, 'dataset': 'few_nerd', 'dataset_fraction': 0.2}]
# model_pars: [{'model_mod': <module 'models.ner.model' from '/home/fipulab/notebooks/robert/p2p_sgd/models/ner/model.py'>, 'bert_config': 'uncased_L-2_H-128_A-2', 'processor_name': 'few', 'lr': 0.0005, 'default_weights': True}]
# graph_pars: {'graph_type': 'sparse', 'num_neighbors': 3, 'directed': True, 'time_varying': -1}
# sim_pars: {'epochs': 300, 'seed': 123, 'print_args': {'print_metrics': ['test_model-macro_avg_f1_score'], 'group_by_dataset': False}}
# Init BertAgent agents:   0%|          | 0/20 [00:00<?, ?it/s]
# Init BertAgent agents: 1 minutes
# Training:   0%|          | 0/26353 [00:00<?, ?it/s]
# ...

# %% [markdown]
# # Sparse -> CoNNL

# %%
from environ import set_visible_devices
set_visible_devices('GPU:1')

from p2p.train import do_train
from p2p.agents import BertAgent
from data.ner import clients_data as ner_clients_data
from models.ner import model as ner_model

do_train(agent_pars={"agent_class": BertAgent, "multi_task_optimization": False, "multi_task_differentiation": 'model'},
         agent_data_pars={"agents_data": ner_clients_data, "num_clients": 20, "batch_size": 50, 'dataset': 'conll'},
         model_pars={"model_mod": ner_model, "bert_config": 'uncased_L-2_H-128_A-2', 'processor_name': 'conll', "lr": 5e-4, "default_weights": True},
         graph_pars={'graph_type': 'sparse', 'num_neighbors': 3, 'directed': True, 'time_varying': -1},
         sim_pars={'epochs': 300, 'seed': 123, 'print_args': {'print_metrics': ['test_model-macro_avg_f1_score'], 'group_by_dataset': False}})
# Out:
# agent_pars: [{'agent_class': <class 'p2p.agents.bert_agent.BertAgent'>, 'multi_task_optimization': False, 'multi_task_differentiation': 'model'}]
# agent_data_pars: [{'agents_data': <module 'data.ner.clients_data' from '/home/fipulab/notebooks/robert/p2p_sgd/data/ner/clients_data.py'>, 'num_clients': 20, 'batch_size': 50, 'dataset': 'conll'}]
# model_pars: [{'model_mod': <module 'models.ner.model' from '/home/fipulab/notebooks/robert/p2p_sgd/models/ner/model.py'>, 'bert_config': 'uncased_L-2_H-128_A-2', 'processor_name': 'conll', 'lr': 0.0005, 'default_weights': True}]
# graph_pars: {'graph_type': 'sparse', 'num_neighbors': 3, 'directed': True, 'time_varying': -1}
# sim_pars: {'epochs': 300, 'seed': 123, 'print_args': {'print_metrics': ['test_model-macro_avg_f1_score'], 'group_by_dataset': False}}
# Init BertAgent agents:   0%|          | 0/20 [00:00<?, ?it/s]
# Init BertAgent agents: 0 minutes
# Training:   0%|          | 0/14041 [00:00<?, ?it/s]
# Msgs: 0	Round: 1	Epoch: 1
# ...

# %% [markdown]
# # Sparse -> StackOverflow

# %%
from environ import set_visible_devices
set_visible_devices('GPU:0')

from p2p.train import do_train
from p2p.agents import BertAgent
from data.stackoverflow import bert_clients_data
from models.nwp import bert_model

do_train(agent_pars={"agent_class": BertAgent, "multi_task_optimization": False, "multi_task_differentiation": 'model'},
         agent_data_pars={"agents_data": bert_clients_data, "num_clients": 20, "batch_size": 50, 'seq_len': 128, 'seed': 123},
         model_pars={"model_mod": bert_model, "bert_config": 'uncased_L-2_H-128_A-2', 'seq_len': 128, "lr": 5e-4, "default_weights": True},
         graph_pars={'graph_type': 'sparse', 'num_neighbors': 3, 'directed': True, 'time_varying': -1},
         sim_pars={'epochs': 300, 'seed': 123, 'print_args': {'print_metrics': ['test_model-sparse_categorical_accuracy'], 'group_by_dataset': False}})
# Out:
# agent_pars: [{'agent_class': <class 'p2p.agents.bert_agent.BertAgent'>, 'multi_task_optimization': False, 'multi_task_differentiation': 'model'}]
# agent_data_pars: [{'agents_data': <module 'data.stackoverflow.bert_clients_data' from '/home/fipulab/notebooks/robert/p2p_sgd/data/stackoverflow/bert_clients_data.py'>, 'num_clients': 20, 'batch_size': 50, 'seq_len': 128, 'seed': 123}]
# model_pars: [{'model_mod': <module 'models.nwp.bert_model' from '/home/fipulab/notebooks/robert/p2p_sgd/models/nwp/bert_model.py'>, 'bert_config': 'uncased_L-2_H-128_A-2', 'seq_len': 128, 'lr': 0.0005, 'default_weights': True}]
# graph_pars: {'graph_type': 'sparse', 'num_neighbors': 3, 'directed': True, 'time_varying': -1}
# sim_pars: {'epochs': 300, 'seed': 123, 'print_args': {'print_metrics': ['test_model-sparse_categorical_accuracy'], 'group_by_dataset': False}}
# Init BertAgent agents:   0%|          | 0/20 [00:00<?, ?it/s]
# ...

# %% [markdown]
# # Sparse -> Reddit

# %%
from environ import set_visible_devices
set_visible_devices('GPU:0')

from p2p.train import do_train
from p2p.agents import BertAgent
from data.reddit import bert_clients_data
from models.nwp import bert_model

do_train(agent_pars={"agent_class": BertAgent, "multi_task_optimization": False, "multi_task_differentiation": 'model'},
         agent_data_pars={"agents_data": bert_clients_data, "num_clients": 20, "batch_size": 50, 'seq_len': 128, 'seed': 123},
         model_pars={"model_mod": bert_model, "bert_config": 'uncased_L-2_H-128_A-2', 'seq_len': 128, "lr": 5e-4, "default_weights": True},
         graph_pars={'graph_type': 'sparse', 'num_neighbors': 3, 'directed': True, 'time_varying': -1},
         sim_pars={'epochs': 300, 'seed': 123, 'print_args': {'print_metrics': ['test_model-sparse_categorical_accuracy'], 'group_by_dataset': False}})
# Out:
# agent_pars: [{'agent_class': <class 'p2p.agents.bert_agent.BertAgent'>, 'multi_task_optimization': False, 'multi_task_differentiation': 'model'}]
# agent_data_pars: [{'agents_data': <module 'data.reddit.bert_clients_data' from '/home/fipulab/notebooks/robert/p2p_sgd/data/reddit/bert_clients_data.py'>, 'num_clients': 20, 'batch_size': 50, 'seq_len': 128, 'seed': 123}]
# model_pars: [{'model_mod': <module 'models.nwp.bert_model' from '/home/fipulab/notebooks/robert/p2p_sgd/models/nwp/bert_model.py'>, 'bert_config': 'uncased_L-2_H-128_A-2', 'seq_len': 128, 'lr': 0.0005, 'default_weights': True}]
# graph_pars: {'graph_type': 'sparse', 'num_neighbors': 3, 'directed': True, 'time_varying': -1}
# sim_pars: {'epochs': 300, 'seed': 123, 'print_args': {'print_metrics': ['test_model-sparse_categorical_accuracy'], 'group_by_dataset': False}}
# Init BertAgent agents:   0%|          | 0/20 [00:00<?, ?it/s]
# ...
