# %%
cd ..
# Out:
# /home/fipulab/notebooks/robert/p2p_bn

# %%
import os
import logging
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
logging.getLogger('tensorflow').setLevel(logging.FATAL)

from fl.train import do_train
import tensorflow as tf
import tensorflow_federated as tff


tff.backends.native.set_local_execution_context(
    server_tf_device=tf.config.list_logical_devices('CPU')[0],
    client_tf_devices=tf.config.list_logical_devices('GPU')[1:])

# %%
for st_cl in [0, 100, 200]:
    do_train(num_clients=100,
             num_train_clients=10,
             batch_size=50,
             epochs=100,
             client_pars={"lr": 0.005},
             server_pars={"lr": 0.005},
             model_v=2,
             seed=123,
             starting_client=st_cl
             )
# Out:
# Seed: 123
# FL training (V=2 num_examples), Num clients per round: 10, batch size: 50, epochs: 100, examples: 68182, server_pars: {'lr': 0.005, 'decay': 0}, client_pars: {'lr': 0.005, 'decay': 0}
#   0%|          | 0/68182 [00:00<?, ?it/s]
# Round: 8	Epoch: 1
# 	Examples: (17788/75757)
# 	Agents	Mean	Median
# Evaluating Train:   0%|          | 0/100 [00:00<?, ?it/s]
# 	Train	0.000%	0.000%
# Evaluating Valid:   0%|          | 0/100 [00:00<?, ?it/s]
# 	Valid	0.000%	0.000%
# Evaluating Test:   0%|          | 0/100 [00:00<?, ?it/s]
# 	Test	0.000%	0.000%
#   0%|          | 0/68182 [00:00<?, ?it/s]
# Round: 19	Epoch: 2
# 	Examples: (22844/155200)
# 	Agents	Mean	Median
# Evaluating Train:   0%|          | 0/100 [00:00<?, ?it/s]
# 	Train	0.000%	0.000%
# Evaluating Valid:   0%|          | 0/100 [00:00<?, ?it/s]
# 	Valid	0.000%	0.000%
# Evaluating Test:   0%|          | 0/100 [00:00<?, ?it/s]
# 	Test	0.000%	0.000%
#   0%|          | 0/68182 [00:00<?, ?it/s]
# Round: 29	Epoch: 3
# ...

# %%
for st_cl in [300, 400]:
    do_train(num_clients=100,
             num_train_clients=10,
             batch_size=50,
             epochs=100,
             client_pars={"lr": 0.005},
             server_pars={"lr": 0.005},
             model_v=2,
             seed=123,
             starting_client=st_cl
             )
# Out:
# Seed: 123
# FL training (V=2 num_examples), Num clients per round: 10, batch size: 50, epochs: 100, examples: 74215, server_pars: {'lr': 0.005, 'decay': 0}, client_pars: {'lr': 0.005, 'decay': 0}
# WARNING:tensorflow:From /home/fipulab/anaconda3/envs/p2p_bn/lib/python3.8/site-packages/tensorflow_federated/python/core/impl/compiler/tensorflow_computation_transformations.py:59: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# WARNING:tensorflow:From /home/fipulab/anaconda3/envs/p2p_bn/lib/python3.8/site-packages/tensorflow_federated/python/core/impl/compiler/tensorflow_computation_transformations.py:59: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# ...

# %%
for st_cl in [0, 500, 1000]:
    do_train(num_clients=500,
             num_train_clients=10,
             batch_size=50,
             epochs=100,
             client_pars={"lr": 0.005},
             server_pars={"lr": 0.005},
             model_v=2,
             seed=123,
             starting_client=st_cl
             )
# Out:
# Seed: 123
# FL training (V=2 num_examples), Num clients per round: 10, batch size: 50, epochs: 100, examples: 327116, server_pars: {'lr': 0.005, 'decay': 0}, client_pars: {'lr': 0.005, 'decay': 0}
#   0%|          | 0/327116 [00:00<?, ?it/s]
# Round: 59	Epoch: 1
# 	Examples: (2330/328412)
# 	Agents	Mean	Median
# Evaluating Train:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Train	5.385%	5.346%
# Evaluating Valid:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Valid	5.142%	5.060%
# Evaluating Test:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Test	5.305%	5.263%
#   0%|          | 0/327116 [00:00<?, ?it/s]
# Round: 108	Epoch: 2
# 	Examples: (17111/665127)
# 	Agents	Mean	Median
# Evaluating Train:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Train	8.181%	8.301%
# Evaluating Valid:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Valid	7.566%	7.578%
# Evaluating Test:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Test	8.215%	8.323%
#   0%|          | 0/327116 [00:00<?, ?it/s]
# Round: 155	Epoch: 3
# ...

# %%
for st_cl in [1500, 2000]:
    do_train(num_clients=500,
             num_train_clients=10,
             batch_size=50,
             epochs=100,
             client_pars={"lr": 0.005},
             server_pars={"lr": 0.005},
             model_v=2,
             seed=123,
             starting_client=st_cl
             )
# Out:
# Seed: 123
# FL training (V=2 num_examples), Num clients per round: 10, batch size: 50, epochs: 100, examples: 380610, server_pars: {'lr': 0.005, 'decay': 0}, client_pars: {'lr': 0.005, 'decay': 0}
#   0%|          | 0/380610 [00:00<?, ?it/s]
# Round: 55	Epoch: 1
# 	Examples: (3361/381470)
# 	Agents	Mean	Median
# Evaluating Train:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Train	6.961%	7.207%
# Evaluating Valid:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Valid	6.956%	7.143%
# Evaluating Test:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Test	6.899%	6.939%
#   0%|          | 0/380610 [00:00<?, ?it/s]
# Round: 109	Epoch: 2
# 	Examples: (10686/765638)
# 	Agents	Mean	Median
# Evaluating Train:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Train	9.307%	9.613%
# Evaluating Valid:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Valid	9.018%	9.200%
# Evaluating Test:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Test	9.446%	9.175%
#   0%|          | 0/380610 [00:00<?, ?it/s]
# Round: 155	Epoch: 3
# ...

# %%
do_train(num_clients=1000,
         num_train_clients=10,
         batch_size=50,
         epochs=100,
         client_pars={"lr": 0.005},
         server_pars={"lr": 0.005},
         model_v=2,
         seed=123,
         starting_client=0
         )
# Out:
# Seed: 123
# FL training (V=2 num_examples), Num clients per round: 10, batch size: 50, epochs: 100, examples: 646252, server_pars: {'lr': 0.005, 'decay': 0}, client_pars: {'lr': 0.005, 'decay': 0}
#   0%|          | 0/646252 [00:00<?, ?it/s]
# Round: 98	Epoch: 1
# 	Examples: (19199/665265)
# 	Agents	Mean	Median
# Evaluating Train:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Train	8.586%	8.747%
# Evaluating Valid:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Valid	8.328%	8.333%
# Evaluating Test:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Test	8.644%	8.752%
#   0%|          | 0/646252 [00:00<?, ?it/s]
# Round: 193	Epoch: 2
# 	Examples: (5112/1294953)
# 	Agents	Mean	Median
# Evaluating Train:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Train	9.559%	9.607%
# Evaluating Valid:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Valid	9.352%	9.375%
# Evaluating Test:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Test	9.488%	9.484%
#   0%|          | 0/646252 [00:00<?, ?it/s]
# Round: 302	Epoch: 3
# ...

# %%
do_train(num_clients=1000,
         num_train_clients=10,
         batch_size=50,
         epochs=100,
         client_pars={"lr": 0.005},
         server_pars={"lr": 0.005},
         model_v=2,
         seed=123,
         starting_client=1000
         )
# Out:
# Seed: 123
# FL training (V=2 num_examples), Num clients per round: 10, batch size: 50, epochs: 100, examples: 709440, server_pars: {'lr': 0.005, 'decay': 0}, client_pars: {'lr': 0.005, 'decay': 0}
#   0%|          | 0/709440 [00:00<?, ?it/s]
# Round: 95	Epoch: 1
# 	Examples: (6234/709530)
# 	Agents	Mean	Median
# Evaluating Train:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Train	7.483%	7.595%
# Evaluating Valid:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Valid	7.277%	7.303%
# Evaluating Test:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Test	7.343%	7.407%
#   0%|          | 0/709440 [00:00<?, ?it/s]
# Round: 203	Epoch: 2
# 	Examples: (11231/1425339)
# 	Agents	Mean	Median
# Evaluating Train:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Train	10.068%	10.128%
# Evaluating Valid:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Valid	9.719%	9.819%
# Evaluating Test:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Test	9.930%	10.000%
#   0%|          | 0/709440 [00:00<?, ?it/s]
# ...

# %%
do_train(num_clients=1000,
         num_train_clients=10,
         batch_size=50,
         epochs=100,
         client_pars={"lr": 0.005},
         server_pars={"lr": 0.005},
         model_v=2,
         seed=123,
         starting_client=2000
         )
# Out:
# Seed: 123
# FL training (V=2 num_examples), Num clients per round: 10, batch size: 50, epochs: 100, examples: 624397, server_pars: {'lr': 0.005, 'decay': 0}, client_pars: {'lr': 0.005, 'decay': 0}
#   0%|          | 0/624397 [00:00<?, ?it/s]
# Round: 108	Epoch: 1
# 	Examples: (5936/626629)
# 	Agents	Mean	Median
# Evaluating Train:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Train	8.191%	8.163%
# Evaluating Valid:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Valid	7.994%	8.000%
# Evaluating Test:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Test	8.295%	8.068%
#   0%|          | 0/624397 [00:00<?, ?it/s]
# Round: 206	Epoch: 2
# 	Examples: (7490/1254189)
# 	Agents	Mean	Median
# Evaluating Train:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Train	9.897%	10.070%
# Evaluating Valid:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Valid	9.525%	9.524%
# Evaluating Test:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Test	9.788%	9.677%
#   0%|          | 0/624397 [00:00<?, ?it/s]
# Round: 314	Epoch: 3
# ...

# %%
do_train(num_clients=1000,
         num_train_clients=10,
         batch_size=50,
         epochs=100,
         client_pars={"lr": 0.005},
         server_pars={"lr": 0.005},
         model_v=2,
         seed=123,
         starting_client=3000
         )
# Out:
# Seed: 123
# FL training (V=2 num_examples), Num clients per round: 10, batch size: 50, epochs: 100, examples: 655706, server_pars: {'lr': 0.005, 'decay': 0}, client_pars: {'lr': 0.005, 'decay': 0}
#   0%|          | 0/655706 [00:00<?, ?it/s]
# Round: 105	Epoch: 1
# 	Examples: (4716/656194)
# 	Agents	Mean	Median
# Evaluating Train:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Train	7.812%	7.923%
# Evaluating Valid:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Valid	8.060%	7.692%
# Evaluating Test:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Test	7.646%	7.692%
#   0%|          | 0/655706 [00:00<?, ?it/s]
# Round: 197	Epoch: 2
# 	Examples: (5303/1314503)
# 	Agents	Mean	Median
# Evaluating Train:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Train	10.230%	10.364%
# Evaluating Valid:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Valid	10.275%	10.000%
# Evaluating Test:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Test	9.962%	10.087%
#   0%|          | 0/655706 [00:00<?, ?it/s]
# ...

# %%
do_train(num_clients=1000,
         num_train_clients=10,
         batch_size=50,
         epochs=100,
         client_pars={"lr": 0.005},
         server_pars={"lr": 0.005},
         model_v=2,
         seed=123,
         starting_client=4000
         )
# Out:
# Seed: 123
# FL training (V=2 num_examples), Num clients per round: 10, batch size: 50, epochs: 100, examples: 724432, server_pars: {'lr': 0.005, 'decay': 0}, client_pars: {'lr': 0.005, 'decay': 0}
#   0%|          | 0/724432 [00:00<?, ?it/s]
# Round: 105	Epoch: 1
# 	Examples: (1935/725081)
# 	Agents	Mean	Median
# Evaluating Train:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Train	8.668%	8.696%
# Evaluating Valid:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Valid	8.580%	8.453%
# Evaluating Test:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Test	8.784%	8.747%
#   0%|          | 0/724432 [00:00<?, ?it/s]
# Round: 209	Epoch: 2
# 	Examples: (22659/1455887)
# 	Agents	Mean	Median
# Evaluating Train:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Train	10.273%	10.385%
# Evaluating Valid:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Valid	9.994%	10.000%
# Evaluating Test:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Test	10.279%	10.268%
#   0%|          | 0/724432 [00:00<?, ?it/s]
# ...
