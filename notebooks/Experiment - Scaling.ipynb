# %%
cd ..
# Out:
# /home/fipulab/notebooks/robert/p2p_sgd

# %%
from environ import set_visible_devices
set_visible_devices('CPU')

from p2p.train import do_train
from p2p.agents import P2PAgent

def train_agents(agent_class, num_clients, st_cl, directed=False):
    do_train(agent_class,
         num_clients=num_clients,
         batch_size=50,
         model_pars={"model_v": 4, "lr": 0.005, "default_weights": True},
         agent_pars={'increase_momentum': True},
         graph_pars={'graph_type': 'sparse', 'num_neighbors': 3, 'directed': directed, 'time_varying': -1},
         epochs=100, seed=123, starting_client=st_cl)

# %% [markdown]
# # Scalling properties
# Increasing mommentum (0.9 - 0.99)

# %% [markdown]
# # Training 100 agents

# %%
train_agents(P2PAgent, 100, 0, directed=True)
# Out:
# Seed: 123
# P2PAgent: 100 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {}
# Init agents:   0%|          | 0/100 [00:00<?, ?it/s]
# Init agents: 1 minutes
# sparse (directed), N: 100, NB: 3, TV: -1
# Training:   0%|          | 0/68182 [00:00<?, ?it/s]
# Msgs: 0	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/100 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		29.070%		18.175%
# 	val_model-accuracy_no_oov:  		3.728%		2.566%
# 	test_model-accuracy_no_oov: 		2.387%		2.072%
# Training:   0%|          | 0/68182 [00:00<?, ?it/s]
# Msgs: 306	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/100 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		10.096%		8.232%
# ...

# %%
train_agents(P2PAgent, 100, 100, directed=True)
# Out:
# Seed: 123
# P2PAgent: 100 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {}
# Init agents:   0%|          | 0/100 [00:00<?, ?it/s]
# Init agents: 1 minutes
# sparse (directed), N: 100, NB: 3, TV: -1
# Training:   0%|          | 0/62596 [00:00<?, ?it/s]
# Msgs: 0	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/100 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		31.194%		22.989%
# 	val_model-accuracy_no_oov:  		2.582%		1.802%
# 	test_model-accuracy_no_oov: 		2.879%		2.410%
# Training:   0%|          | 0/62596 [00:00<?, ?it/s]
# Msgs: 264	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/100 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		9.778%		8.426%
# ...

# %%
train_agents(P2PAgent, 100, 200, directed=True)
# Out:
# Seed: 123
# P2PAgent: 100 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {}
# Init agents:   0%|          | 0/100 [00:00<?, ?it/s]
# Init agents: 1 minutes
# sparse (directed), N: 100, NB: 3, TV: -1
# Training:   0%|          | 0/76104 [00:00<?, ?it/s]
# Msgs: 0	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/100 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		32.313%		24.468%
# 	val_model-accuracy_no_oov:  		3.225%		2.039%
# 	test_model-accuracy_no_oov: 		3.180%		2.174%
# Training:   0%|          | 0/76104 [00:00<?, ?it/s]
# Msgs: 261	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/100 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		10.247%		8.118%
# ...

# %%
train_agents(P2PAgent, 100, 300, directed=True)
# Out:
# Seed: 123
# P2PAgent: 100 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {'increase_momentum': True}
# Init agents:   0%|          | 0/100 [00:00<?, ?it/s]
# Init agents: 1 minutes
# sparse (directed), N: 100, NB: 3, TV: -1
# Training:   0%|          | 0/74215 [00:00<?, ?it/s]
# Msgs: 0	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/100 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		28.763%		20.509%
# 	val_model-accuracy_no_oov:  		2.983%		2.372%
# 	test_model-accuracy_no_oov: 		2.650%		1.987%
# Training:   0%|          | 0/74215 [00:00<?, ?it/s]
# Msgs: 447	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/100 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# ...

# %%
train_agents(P2PAgent, 100, 400, directed=True)
# Out:
# Seed: 123
# P2PAgent: 100 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {'increase_momentum': True}
# Init agents:   0%|          | 0/100 [00:00<?, ?it/s]
# Init agents: 1 minutes
# sparse (directed), N: 100, NB: 3, TV: -1
# Training:   0%|          | 0/46019 [00:00<?, ?it/s]
# Msgs: 0	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/100 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		34.835%		25.520%
# 	val_model-accuracy_no_oov:  		2.569%		2.008%
# 	test_model-accuracy_no_oov: 		2.481%		1.879%
# Training:   0%|          | 0/46019 [00:00<?, ?it/s]
# Msgs: 306	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/100 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# ...

# %% [markdown]
# # Training 500 agents

# %% [markdown]
# ### GoSGD

# %%
train_agents(GoSGDAgent, 500, 0, agent_pars={'p': 0.1, 'use_graph': True})
# Out:
# Seed: 123
# GoSGDAgent: 500 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {'p': 0.1, 'use_graph': True}
# Init agents:   0%|          | 0/500 [00:00<?, ?it/s]
# Init agents: 5 minutes
# sparse (directed), N: 500, NB: 3, TV: -1
# Training:   0%|          | 0/327116 [00:00<?, ?it/s]
# Msgs: 2145	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		33.624%		21.273%
# 	val_model-accuracy_no_oov:  		3.451%		2.778%
# 	test_model-accuracy_no_oov: 		3.552%		2.896%
# Training:   0%|          | 0/327116 [00:00<?, ?it/s]
# Msgs: 4533	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# ...

# %%
train_agents(GoSGDAgent, 500, 500, agent_pars={'p': 0.1, 'use_graph': True})
# Out:
# Seed: 123
# GoSGDAgent: 500 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {'p': 0.1, 'use_graph': True}
# Init agents:   0%|          | 0/500 [00:00<?, ?it/s]
# Init agents: 5 minutes
# sparse (directed), N: 500, NB: 3, TV: -1
# Training:   0%|          | 0/319136 [00:00<?, ?it/s]
# Msgs: 2145	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		33.014%		21.749%
# 	val_model-accuracy_no_oov:  		3.577%		2.941%
# 	test_model-accuracy_no_oov: 		3.299%		2.983%
# Training:   0%|          | 0/319136 [00:00<?, ?it/s]
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# ...

# %%
train_agents(GoSGDAgent, 500, 1000, agent_pars={'p': 0.1, 'use_graph': True})
# Out:
# Seed: 123
# GoSGDAgent: 500 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {'p': 0.1, 'use_graph': True}
# Init agents:   0%|          | 0/500 [00:00<?, ?it/s]
# Init agents: 5 minutes
# sparse (directed), N: 500, NB: 3, TV: -1
# Training:   0%|          | 0/328830 [00:00<?, ?it/s]
# Msgs: 2145	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		32.574%		22.045%
# 	val_model-accuracy_no_oov:  		3.429%		2.985%
# 	test_model-accuracy_no_oov: 		3.494%		2.999%
# Training:   0%|          | 0/328830 [00:00<?, ?it/s]
# Msgs: 4533	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# ...

# %%
train_agents(GoSGDAgent, 500, 1500, agent_pars={'p': 0.1, 'use_graph': True})
# Out:
# Seed: 123
# GoSGDAgent: 500 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {'p': 0.1, 'use_graph': True}
# Init agents:   0%|          | 0/500 [00:00<?, ?it/s]
# Init agents: 6 minutes
# sparse (directed), N: 500, NB: 3, TV: -1
# Training:   0%|          | 0/380610 [00:00<?, ?it/s]
# Msgs: 2592	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		30.229%		19.601%
# 	val_model-accuracy_no_oov:  		4.034%		3.279%
# 	test_model-accuracy_no_oov: 		3.788%		3.299%
# Training:   0%|          | 0/380610 [00:00<?, ?it/s]
# Msgs: 5181	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# ...

# %%
train_agents(GoSGDAgent, 500, 2000, agent_pars={'p': 0.1, 'use_graph': True})
# Out:
# Seed: 123
# GoSGDAgent: 500 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {'p': 0.1, 'use_graph': True}
# Init agents:   0%|          | 0/500 [00:00<?, ?it/s]
# Init agents: 6 minutes
# sparse (directed), N: 500, NB: 3, TV: -1
# Training:   0%|          | 0/288183 [00:00<?, ?it/s]
# Msgs: 2031	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		31.366%		21.025%
# 	val_model-accuracy_no_oov:  		4.047%		3.116%
# 	test_model-accuracy_no_oov: 		3.602%		2.922%
# Training:   0%|          | 0/288183 [00:00<?, ?it/s]
# Msgs: 3852	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# ...

# %% [markdown]
# ### D$^2$

# %%
train_agents(D2Agent, 500, 0)
# Out:
# Seed: 123
# D2Agent: 500 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {}
# Init agents:   0%|          | 0/500 [00:00<?, ?it/s]
# Init agents: 5 minutes
# sparse (directed), N: 500, NB: 3, TV: -1
# Training:   0%|          | 0/327116 [00:00<?, ?it/s]
# Msgs: 21000	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		6.042%		5.263%
# 	val_model-accuracy_no_oov:  		3.921%		3.559%
# 	test_model-accuracy_no_oov: 		4.436%		4.167%
# Training:   0%|          | 0/327116 [00:00<?, ?it/s]
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# ...

# %%
train_agents(D2Agent, 500, 500)
# Out:
# Seed: 123
# D2Agent: 500 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {}
# Init agents:   0%|          | 0/500 [00:00<?, ?it/s]
# Init agents: 6 minutes
# sparse (directed), N: 500, NB: 3, TV: -1
# Training:   0%|          | 0/319136 [00:00<?, ?it/s]
# Msgs: 21000	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		5.846%		5.282%
# 	val_model-accuracy_no_oov:  		4.568%		4.121%
# 	test_model-accuracy_no_oov: 		4.296%		4.082%
# Training:   0%|          | 0/319136 [00:00<?, ?it/s]
# Msgs: 43500	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# ...

# %%
train_agents(D2Agent, 500, 1000)
# Out:
# Seed: 123
# D2Agent: 500 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {}
# Init agents:   0%|          | 0/500 [00:00<?, ?it/s]
# Init agents: 6 minutes
# sparse (directed), N: 500, NB: 3, TV: -1
# Training:   0%|          | 0/328830 [00:00<?, ?it/s]
# Msgs: 21000	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		5.945%		5.263%
# 	val_model-accuracy_no_oov:  		4.074%		3.571%
# 	test_model-accuracy_no_oov: 		4.052%		3.716%
# Training:   0%|          | 0/328830 [00:00<?, ?it/s]
# Msgs: 45000	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		6.646%		6.113%
# ...

# %%
train_agents(D2Agent, 500, 1500)
# Out:
# Seed: 123
# D2Agent: 500 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {}
# Init agents:   0%|          | 0/500 [00:00<?, ?it/s]
# Init agents: 6 minutes
# sparse (directed), N: 500, NB: 3, TV: -1
# Training:   0%|          | 0/380610 [00:00<?, ?it/s]
# Msgs: 25500	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		6.289%		5.651%
# 	val_model-accuracy_no_oov:  		4.700%		4.321%
# 	test_model-accuracy_no_oov: 		4.734%		4.545%
# Training:   0%|          | 0/380610 [00:00<?, ?it/s]
# Msgs: 51000	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		6.491%		6.104%
# ...

# %%
train_agents(D2Agent, 500, 2000)
# Out:
# Seed: 123
# D2Agent: 500 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {}
# Init agents:   0%|          | 0/500 [00:00<?, ?it/s]
# Init agents: 5 minutes
# sparse (directed), N: 500, NB: 3, TV: -1
# Training:   0%|          | 0/288183 [00:00<?, ?it/s]
# Msgs: 19500	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		5.804%		5.169%
# 	val_model-accuracy_no_oov:  		4.456%		3.904%
# 	test_model-accuracy_no_oov: 		4.067%		3.901%
# Training:   0%|          | 0/288183 [00:00<?, ?it/s]
# Msgs: 39000	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		6.624%		5.961%
# ...

# %% [markdown]
# ### SGP

# %%
train_agents(SGPPushSumAgent, 500, 0)
# Out:
# Seed: 123
# SGPPushSumAgent: 500 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {}
# Init agents:   0%|          | 0/500 [00:00<?, ?it/s]
# Init agents: 6 minutes
# sparse (directed), N: 500, NB: 3, TV: -1
# Training:   0%|          | 0/327116 [00:00<?, ?it/s]
# Msgs: 22500	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		3.868%		3.451%
# 	val_model-accuracy_no_oov:  		2.697%		2.222%
# 	test_model-accuracy_no_oov: 		3.038%		2.703%
# Training:   0%|          | 0/327116 [00:00<?, ?it/s]
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# ...

# %%
train_agents(SGPPushSumAgent, 500, 500)
# Out:
# Seed: 123
# SGPPushSumAgent: 500 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {}
# Init agents:   0%|          | 0/500 [00:00<?, ?it/s]
# Init agents: 6 minutes
# sparse (directed), N: 500, NB: 3, TV: -1
# Training:   0%|          | 0/319136 [00:00<?, ?it/s]
# Msgs: 22500	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		3.624%		3.262%
# 	val_model-accuracy_no_oov:  		2.851%		2.528%
# 	test_model-accuracy_no_oov: 		2.853%		2.564%
# Training:   0%|          | 0/319136 [00:00<?, ?it/s]
# Msgs: 45000	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		5.265%		4.929%
# ...

# %%
train_agents(SGPPushSumAgent, 500, 1000)
# Out:
# Seed: 123
# SGPPushSumAgent: 500 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {}
# Init agents:   0%|          | 0/500 [00:00<?, ?it/s]
# Init agents: 6 minutes
# sparse (directed), N: 500, NB: 3, TV: -1
# Training:   0%|          | 0/328830 [00:00<?, ?it/s]
# Msgs: 22500	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		3.627%		3.141%
# 	val_model-accuracy_no_oov:  		2.755%		2.065%
# 	test_model-accuracy_no_oov: 		2.601%		2.278%
# Training:   0%|          | 0/328830 [00:00<?, ?it/s]
# Msgs: 46500	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		5.458%		5.058%
# ...

# %%
train_agents(SGPPushSumAgent, 500, 1500)
# Out:
# Seed: 123
# SGPPushSumAgent: 500 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {}
# Init agents:   0%|          | 0/500 [00:00<?, ?it/s]
# Init agents: 6 minutes
# sparse (directed), N: 500, NB: 3, TV: -1
# Training:   0%|          | 0/380610 [00:00<?, ?it/s]
# Msgs: 27000	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		4.155%		3.864%
# 	val_model-accuracy_no_oov:  		3.291%		2.836%
# 	test_model-accuracy_no_oov: 		3.299%		2.999%
# Training:   0%|          | 0/380610 [00:00<?, ?it/s]
# Msgs: 52500	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		5.552%		5.219%
# ...

# %%
train_agents(SGPPushSumAgent, 500, 2000)
# Out:
# Seed: 123
# SGPPushSumAgent: 500 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {}
# Init agents:   0%|          | 0/500 [00:00<?, ?it/s]
# Init agents: 5 minutes
# sparse (directed), N: 500, NB: 3, TV: -1
# Training:   0%|          | 0/288183 [00:00<?, ?it/s]
# Msgs: 21000	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		3.687%		3.410%
# 	val_model-accuracy_no_oov:  		2.717%		2.247%
# 	test_model-accuracy_no_oov: 		2.727%		2.439%
# Training:   0%|          | 0/288183 [00:00<?, ?it/s]
# Msgs: 40500	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		5.164%		4.747%
# ...

# %% [markdown]
# ### P2P-BN

# %%
train_agents(P2PAgent, 500, 0, directed=True)
# Out:
# Seed: 123
# P2PAgent: 500 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {}
# Init agents:   0%|          | 0/500 [00:00<?, ?it/s]
# Init agents: 7 minutes
# sparse (directed), N: 500, NB: 3, TV: -1
# Training:   0%|          | 0/327116 [00:00<?, ?it/s]
# Msgs: 0	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		31.246%		22.783%
# 	val_model-accuracy_no_oov:  		3.032%		2.174%
# 	test_model-accuracy_no_oov: 		2.719%		2.020%
# Training:   0%|          | 0/327116 [00:00<?, ?it/s]
# Msgs: 1491	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		9.288%		6.667%
# ...

# %%
train_agents(P2PAgent, 500, 500, directed=True)
# Out:
# Seed: 123
# P2PAgent: 500 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {}
# Init agents:   0%|          | 0/500 [00:00<?, ?it/s]
# Init agents: 7 minutes
# sparse (directed), N: 500, NB: 3, TV: -1
# Training:   0%|          | 0/319136 [00:00<?, ?it/s]
# Msgs: 0	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		30.809%		22.406%
# 	val_model-accuracy_no_oov:  		3.092%		2.069%
# 	test_model-accuracy_no_oov: 		2.494%		1.829%
# Training:   0%|          | 0/319136 [00:00<?, ?it/s]
# Msgs: 1350	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		9.721%		6.959%
# ...

# %%
train_agents(P2PAgent, 500, 1000, directed=True)
# Out:
# Seed: 123
# P2PAgent: 500 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {}
# Init agents:   0%|          | 0/500 [00:00<?, ?it/s]
# Init agents: 5 minutes
# sparse (directed), N: 500, NB: 3, TV: -1
# Training:   0%|          | 0/328830 [00:00<?, ?it/s]
# Msgs: 0	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		31.144%		23.698%
# 	val_model-accuracy_no_oov:  		2.791%		1.903%
# 	test_model-accuracy_no_oov: 		2.746%		1.818%
# Training:   0%|          | 0/328830 [00:00<?, ?it/s]
# Msgs: 1263	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		10.218%		7.523%
# ...

# %%
train_agents(P2PAgent, 500, 1500, directed=True)
# Out:
# Seed: 123
# P2PAgent: 500 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {'increase_momentum': True}
# Init agents:   0%|          | 0/500 [00:00<?, ?it/s]
# Init agents: 6 minutes
# sparse (directed), N: 500, NB: 3, TV: -1
# Training:   0%|          | 0/380610 [00:00<?, ?it/s]
# Msgs: 0	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		29.271%		20.224%
# 	val_model-accuracy_no_oov:  		3.002%		1.653%
# 	test_model-accuracy_no_oov: 		3.089%		2.031%
# Training:   0%|          | 0/380610 [00:00<?, ?it/s]
# Msgs: 1461	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# ...

# %%
train_agents(P2PAgent, 500, 2000, directed=True)
# Out:
# Seed: 123
# P2PAgent: 500 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {'increase_momentum': True}
# Init agents:   0%|          | 0/500 [00:00<?, ?it/s]
# Init agents: 6 minutes
# sparse (directed), N: 500, NB: 3, TV: -1
# Training:   0%|          | 0/288183 [00:00<?, ?it/s]
# Msgs: 0	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/500 [00:00<?, ?it/s]
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		8.841%		7.714%
# 	val_model-accuracy_no_oov:  		6.729%		6.474%
# ...

# %% [markdown]
# # Training 1000 agents

# %%
train_agents(P2PAgent, 1000, 0, directed=True)
# Out:
# Seed: 123
# P2PAgent: 1000 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {}
# Init agents:   0%|          | 0/1000 [00:00<?, ?it/s]
# Init agents: 16 minutes
# sparse (directed), N: 1000, NB: 3, TV: -1
# Training:   0%|          | 0/646252 [00:00<?, ?it/s]
# Msgs: 0	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		30.970%		22.488%
# 	val_model-accuracy_no_oov:  		3.003%		1.887%
# 	test_model-accuracy_no_oov: 		2.628%		2.000%
# Training:   0%|          | 0/646252 [00:00<?, ?it/s]
# Msgs: 3318	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		9.090%		6.697%
# ...

# %%
train_agents(P2PAgent, 1000, 1000, directed=True)
# Out:
# Seed: 123
# P2PAgent: 1000 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {}
# Init agents:   0%|          | 0/1000 [00:00<?, ?it/s]
# Init agents: 12 minutes
# sparse (directed), N: 1000, NB: 3, TV: -1
# Training:   0%|          | 0/709440 [00:00<?, ?it/s]
# Msgs: 0	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		30.187%		21.875%
# 	val_model-accuracy_no_oov:  		2.958%		1.928%
# 	test_model-accuracy_no_oov: 		2.973%		1.981%
# Training:   0%|          | 0/709440 [00:00<?, ?it/s]
# Msgs: 2736	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		9.698%		7.238%
# ...

# %%
train_agents(P2PAgent, 1000, 2000, directed=True)
# Out:
# Seed: 123
# P2PAgent: 1000 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {}
# Init agents:   0%|          | 0/1000 [00:00<?, ?it/s]
# Init agents: 12 minutes
# sparse (directed), N: 1000, NB: 3, TV: -1
# Training:   0%|          | 0/624397 [00:00<?, ?it/s]
# Msgs: 0	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		30.508%		21.756%
# 	val_model-accuracy_no_oov:  		2.760%		1.835%
# 	test_model-accuracy_no_oov: 		2.770%		1.974%
# Training:   0%|          | 0/624397 [00:00<?, ?it/s]
# Msgs: 2853	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		9.493%		6.973%
# ...

# %%
train_agents(P2PAgent, 1000, 3000, directed=True)
# Out:
# Seed: 123
# P2PAgent: 1000 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {'increase_momentum': True}
# Init agents:   0%|          | 0/1000 [00:00<?, ?it/s]
# Init agents: 33 minutes
# sparse (directed), N: 1000, NB: 3, TV: -1
# Training:   0%|          | 0/655706 [00:00<?, ?it/s]
# Msgs: 0	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		31.852%		23.912%
# 	val_model-accuracy_no_oov:  		2.990%		1.843%
# 	test_model-accuracy_no_oov: 		2.836%		2.021%
# Training:   0%|          | 0/655706 [00:00<?, ?it/s]
# Msgs: 3453	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# ...

# %%
train_agents(P2PAgent, 1000, 4000, directed=True)
# Out:
# Seed: 123
# P2PAgent: 1000 agents, batch size: 50, model_pars: {'model_v': 4, 'lr': 0.005, 'decay': 0, 'default_weights': True}, agent_pars: {'increase_momentum': True}
# Init agents:   0%|          | 0/1000 [00:00<?, ?it/s]
# Init agents: 12 minutes
# sparse (directed), N: 1000, NB: 3, TV: -1
# Training:   0%|          | 0/724432 [00:00<?, ?it/s]
# Msgs: 0	Round: 1	Epoch: 1
# Evaluating agents:   0%|          | 0/1000 [00:00<?, ?it/s]
# 	Metric                      		Mean		Median
# 	---------------------------------------------------------------
# 	train_model-accuracy_no_oov:		29.919%		22.134%
# 	val_model-accuracy_no_oov:  		3.060%		1.994%
# 	test_model-accuracy_no_oov: 		2.959%		2.222%
# Training:   0%|          | 0/724432 [00:00<?, ?it/s]
# Msgs: 2886	Round: 2	Epoch: 2
# Evaluating agents:   0%|          | 0/1000 [00:00<?, ?it/s]
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# ...
